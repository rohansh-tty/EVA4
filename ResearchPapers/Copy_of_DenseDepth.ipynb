# %%
# %tensorflow_version 1.x
# %matplotlib inline
# Out:
# TensorFlow 1.x selected.

# %%
# !git clone https://github.com/ialhashim/DenseDepth.git
# Out:
# Cloning into 'DenseDepth'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 238 (delta 0), reused 1 (delta 0), pack-reused 235
# Receiving objects: 100% (238/238), 11.80 MiB | 20.17 MiB/s, done.
# Resolving deltas: 100% (115/115), done.

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
# Upload few images to test folder
os.chdir("/content/DenseDepth")
# !ls
# !mkdir test/
# Out:
# augment.py	demo.py		  examples   model.py	 test.py
# callbacks.py	demo_rgb.npy	  layers.py  PyTorch	 train.py
# data.py		DenseDepth.ipynb  LICENSE    README.md	 utils.py
# demo_depth.npy	evaluate.py	  loss.py    Tensorflow

# %%
# !wget https://s3-eu-west-1.amazonaws.com/densedepth/nyu.h5 -O ./nyu.h5
# Out:
# --2020-07-14 14:42:38--  https://s3-eu-west-1.amazonaws.com/densedepth/nyu.h5
# Resolving s3-eu-west-1.amazonaws.com (s3-eu-west-1.amazonaws.com)... 52.218.80.146
# Connecting to s3-eu-west-1.amazonaws.com (s3-eu-west-1.amazonaws.com)|52.218.80.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 172897376 (165M) [application/h5]
# Saving to: ‘./nyu.h5’
#
# ./nyu.h5            100%[===================>] 164.89M  16.4MB/s    in 11s
#
# 2020-07-14 14:42:49 (15.4 MB/s) - ‘./nyu.h5’ saved [172897376/172897376]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !cd /content/drive/My\ Drive/S15\ Dataset

# %%
# !cd /content/drive/My\ Drive/FG_BG ; python /content/DenseDepth/test.py --model /content/DenseDepth/nyu.h5 --input "/content/drive/My Drive/test_depth/*.jpeg"
# Out:
# Using TensorFlow backend.
# Loading model...
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4074: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From /content/DenseDepth/layers.py:38: The name tf.image.resize_images is deprecated. Please use tf.image.resize instead.
#
#
# Model loaded (/content/DenseDepth/nyu.h5).
#
# ...

# %%
# Out:
# Using TensorFlow backend.
# Loading model...
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4074: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From /content/DenseDepth/layers.py:38: The name tf.image.resize_images is deprecated. Please use tf.image.resize instead.
#
#
# Model loaded (nyu.h5).
#
# Loaded (11) images of size (224, 224, 3).
# ...

# %%
# !cd /content/DenseDepth ; python /content/DenseDepth/test.py  --input "/content/DenseDepth/test/*.jpeg"
# Out:
# Using TensorFlow backend.
# Loading model...
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4074: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From /content/DenseDepth/layers.py:38: The name tf.image.resize_images is deprecated. Please use tf.image.resize instead.
#
#
# Model loaded (nyu.h5).
#
# Loaded (11) images of size (224, 224, 3).
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
from matplotlib import pyplot as plt
from skimage import io

plt.figure(figsize=(150,100))
plt.imshow( io.imread("/content/DenseDepth/test.png") )
