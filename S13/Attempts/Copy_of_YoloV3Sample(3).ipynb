# %% [markdown]
# # **Motivation**:
#  Waste Segregator Robo which seperates Recyclable & Non-Recyclable Waste Materials and dumps them into resp bins.
#
# **Number of Classes**: 5(Recyclable-4, Non-Recyclable-1)
#
# **[*Cardboard, Metal-Can, Newspaper, PaperTowel/Tissue, Plastic*]**

# %% [markdown]
# # ***Steps to Follow:***

# %% [markdown]
# **1. Clone the Github Repo**

# %%
# !git clone https://github.com/Gilf641/YoloV3.git
# Out:
# Cloning into 'YoloV3'...
# remote: Enumerating objects: 980, done.
# remote: Counting objects: 100% (980/980), done.
# remote: Compressing objects: 100% (913/913), done.
# remote: Total 1454 (delta 0), reused 976 (delta 0), pack-reused 474
# Receiving objects: 100% (1454/1454), 20.93 MiB | 5.56 MiB/s, done.
# Resolving deltas: 100% (79/79), done.

# %% [markdown]
# **2. Mount Google Drive**

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# **3. Display Framework & Device Properties**

# %%
import time
import glob
import torch
import os

from IPython.display import Image, clear_output 
print('PyTorch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# PyTorch 1.5.1+cu101 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15079MB, multi_processor_count=40)

# %%
ls
# Out:
# gdrive/  sample_data/  YoloV3/

# %% [markdown]
# **4. Change current working directory to YoloV3/**

# %%
cd YoloV3/
# Out:
# /content/YoloV3

# %%
# !ls
# Out:
#  annotation_tool   output	  results.txt	     train.py
#  cfg		   __pycache__	  test_batch0.png   'ubdivisions=1'
#  data		   README.md	  test.py	     utils
#  detect.py	   results.json   ting		     vim.exe.stackdump
#  models.py	   results.png	  train_batch0.png

# %% [markdown]
# **5. Add Weights Folder and paste YoloV3 Weights**

# %%
! mkdir weights 
# !cd weights/
! wget https://pjreddie.com/media/files/yolov3.weights
# Out:
# --2020-07-02 11:17:25--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights        0%[                    ] 215.70K  98.6KB/s               ^C

# %% [markdown]
# **6. Train YoloV3 on smalcoco**

# %%
# !python train.py --data data/smalcoco/smalcoco.data --batch 3 --cache --epochs 15 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=3, bucket='', cache_images=True, cfg='cfg/yolov3-spp.cfg', data='data/smalcoco/smalcoco.data', device='', epochs=15, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# 2020-07-02 11:18:16.586212: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# batch=64
# subdivisions=16
# width=608
# height=608
# channels=3
# momentum=0.9
# decay=0.0005
# angle=0
# saturation = 1.5
# exposure = 1.5
# hue=.1
# learning_rate=0.001
# burn_in=1000
# max_batches = 500200
# policy=steps
# steps=400000,450000
# scales=.1,.1
# batch_normalize=1
# filters=32
# size=3
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=64
# size=3
# stride=2
# pad=1
# activation=leaky
# batch_normalize=1
# filters=32
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=64
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=128
# size=3
# stride=2
# pad=1
# activation=leaky
# batch_normalize=1
# filters=64
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=128
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=64
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=128
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=256
# size=3
# stride=2
# pad=1
# activation=leaky
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=256
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=256
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=256
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=256
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=256
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=256
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=256
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=256
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=512
# size=3
# stride=2
# pad=1
# activation=leaky
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=512
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=512
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=512
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=512
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=512
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=512
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=512
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=512
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=1024
# size=3
# stride=2
# pad=1
# activation=leaky
# batch_normalize=1
# filters=512
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=1024
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=512
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=1024
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=512
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=1024
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=512
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=1024
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=512
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# size=3
# stride=1
# pad=1
# filters=1024
# activation=leaky
# batch_normalize=1
# filters=512
# size=1
# stride=1
# pad=1
# activation=leaky
# stride=1
# size=5
# layers=-2
# stride=1
# size=9
# layers=-4
# stride=1
# size=13
# layers=-1,-3,-5,-6
# batch_normalize=1
# filters=512
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# size=3
# stride=1
# pad=1
# filters=1024
# activation=leaky
# batch_normalize=1
# filters=512
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# size=3
# stride=1
# pad=1
# filters=1024
# activation=leaky
# size=1
# stride=1
# pad=1
# filters=255
# activation=linear
# mask = 6,7,8
# anchors = 10,13,  16,30,  33,23,  30,61,  62,45,  59,119,  116,90,  156,198,  373,326
# classes=80
# num=9
# jitter=.3
# ignore_thresh = .7
# truth_thresh = 1
# random=1
# layers = -4
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
# stride=2
# layers = -1, 61
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# size=3
# stride=1
# pad=1
# filters=512
# activation=leaky
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# size=3
# stride=1
# pad=1
# filters=512
# activation=leaky
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# size=3
# stride=1
# pad=1
# filters=512
# activation=leaky
# size=1
# stride=1
# pad=1
# filters=255
# activation=linear
# mask = 3,4,5
# anchors = 10,13,  16,30,  33,23,  30,61,  62,45,  59,119,  116,90,  156,198,  373,326
# classes=80
# num=9
# jitter=.3
# ignore_thresh = .7
# truth_thresh = 1
# random=1
# layers = -4
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
# stride=2
# layers = -1, 36
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# size=3
# stride=1
# pad=1
# filters=256
# activation=leaky
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# size=3
# stride=1
# pad=1
# filters=256
# activation=leaky
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# size=3
# stride=1
# pad=1
# filters=256
# activation=leaky
# size=1
# stride=1
# pad=1
# filters=255
# activation=linear
# mask = 0,1,2
# anchors = 10,13,  16,30,  33,23,  30,61,  62,45,  59,119,  116,90,  156,198,  373,326
# classes=80
# num=9
# jitter=.3
# ignore_thresh = .7
# truth_thresh = 1
# random=1
# Model Summary: 225 layers, 6.29987e+07 parameters, 6.29987e+07 gradients
# Caching labels (20 found, 0 missing, 0 empty, 0 duplicate, for 20 images): 100% 20/20 [00:00<00:00, 6014.63it/s]
# Caching images (0.0GB): 100% 20/20 [00:00<00:00, 112.82it/s]
# Caching labels (20 found, 0 missing, 0 empty, 0 duplicate, for 20 images): 100% 20/20 [00:00<00:00, 7032.70it/s]
# Caching images (0.0GB): 100% 20/20 [00:00<00:00, 97.20it/s]
# Image sizes 512 - 512 train, 512 test
# Using 2 dataloader workers
# Starting training for 15 epochs...
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#       0/14     3.05G      1.89      2.14     0.445      4.48        21       512: 100% 7/7 [00:06<00:00,  1.05it/s]
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100% 7/7 [00:02<00:00,  2.81it/s]
#                  all        20       128     0.582     0.954     0.934     0.709
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#       1/14     3.05G      1.69      1.57     0.613      3.88        18       512: 100% 7/7 [00:02<00:00,  2.48it/s]
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100% 7/7 [00:00<00:00,  9.10it/s]
#                  all        20       128     0.577     0.968     0.945     0.709
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#       2/14     3.05G      1.47      1.39     0.495      3.36         9       512: 100% 7/7 [00:02<00:00,  2.50it/s]
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100% 7/7 [00:00<00:00,  9.13it/s]
#                  all        20       128      0.57     0.968     0.946     0.704
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#       3/14     3.05G      1.86      2.06     0.303      4.22        33       512: 100% 7/7 [00:02<00:00,  2.48it/s]
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100% 7/7 [00:00<00:00,  8.39it/s]
#                  all        20       128     0.567     0.968     0.945     0.702
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#       4/14     3.05G      1.51      1.77     0.456      3.73         7       512: 100% 7/7 [00:02<00:00,  2.46it/s]
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100% 7/7 [00:00<00:00,  8.86it/s]
#                  all        20       128     0.566     0.968     0.946     0.701
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#       5/14     3.05G      2.05      1.63     0.753      4.43        15       512: 100% 7/7 [00:02<00:00,  2.44it/s]
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100% 7/7 [00:00<00:00,  8.55it/s]
#                  all        20       128     0.564     0.975     0.948     0.701
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#       6/14     3.05G      1.69      1.44     0.726      3.85        27       512: 100% 7/7 [00:02<00:00,  2.42it/s]
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100% 7/7 [00:00<00:00,  8.91it/s]
#                  all        20       128     0.563     0.977     0.947     0.701
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#       7/14     3.05G       1.8      1.32     0.317      3.43        12       512: 100% 7/7 [00:02<00:00,  2.44it/s]
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100% 7/7 [00:00<00:00,  8.31it/s]
#                  all        20       128     0.562     0.977     0.955       0.7
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#       8/14     3.05G      1.78      1.78      0.41      3.97         6       512: 100% 7/7 [00:02<00:00,  2.40it/s]
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100% 7/7 [00:00<00:00,  9.01it/s]
#                  all        20       128     0.556      0.98     0.958     0.696
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#       9/14     3.05G      1.76      1.59     0.271      3.62        10       512: 100% 7/7 [00:02<00:00,  2.40it/s]
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100% 7/7 [00:00<00:00,  8.42it/s]
#                  all        20       128     0.547     0.977     0.956     0.688
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      10/14     3.05G      1.79      1.84     0.269       3.9        14       512: 100% 7/7 [00:02<00:00,  2.37it/s]
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100% 7/7 [00:00<00:00,  8.75it/s]
#                  all        20       128     0.548     0.977     0.955     0.689
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      11/14     3.05G      1.71      1.62     0.331      3.66        19       512: 100% 7/7 [00:02<00:00,  2.39it/s]
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100% 7/7 [00:00<00:00,  8.75it/s]
#                  all        20       128     0.547     0.978     0.956     0.688
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      12/14     3.05G      1.82      2.03     0.341      4.19        37       512: 100% 7/7 [00:02<00:00,  2.37it/s]
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100% 7/7 [00:00<00:00,  8.73it/s]
#                  all        20       128     0.545     0.981     0.956     0.687
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      13/14     3.05G      1.76       1.7     0.612      4.07        21       512: 100% 7/7 [00:02<00:00,  2.35it/s]
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100% 7/7 [00:00<00:00,  8.74it/s]
#                  all        20       128     0.548     0.984     0.956     0.692
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      14/14     3.05G      1.78      1.24      0.98      4.01        10       512: 100% 7/7 [00:02<00:00,  2.34it/s]
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100% 7/7 [00:00<00:00,  8.40it/s]
#                  all        20       128     0.553     0.984     0.956     0.696
# Speed: 22.5/2.0/24.5 ms inference/NMS/total per 512x512 image at batch-size 3
# 15 epochs completed in 0.018 hours.

# %% [markdown]
# **7. Train YoloV3 on Custom Dataset(WasteMaterials in my case)**

# %%
# !python train.py --data data/customdata/custom.data --batch 10 --cache --cfg cfg/yolov3-custom.cfg --epochs 60 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=10, bucket='', cache_images=True, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', device='', epochs=60, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# 2020-07-02 16:40:39.583138: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# batch=64
# subdivisions=16
# width=608
# height=608
# channels=3
# momentum=0.9
# decay=0.0005
# angle=0
# saturation = 1.5
# exposure = 1.5
# hue=.1
# learning_rate=0.001
# burn_in=1000
# max_batches = 500200
# policy=steps
# steps=400000,450000
# scales=.1,.1
# batch_normalize=1
# filters=32
# size=3
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=64
# size=3
# stride=2
# pad=1
# activation=leaky
# batch_normalize=1
# filters=32
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=64
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=128
# size=3
# stride=2
# pad=1
# activation=leaky
# batch_normalize=1
# filters=64
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=128
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=64
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=128
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=256
# size=3
# stride=2
# pad=1
# activation=leaky
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=256
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=256
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=256
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=256
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=256
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=256
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=256
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=256
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=512
# size=3
# stride=2
# pad=1
# activation=leaky
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=512
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=512
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=512
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=512
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=512
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=512
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=512
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=512
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=1024
# size=3
# stride=2
# pad=1
# activation=leaky
# batch_normalize=1
# filters=512
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=1024
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=512
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=1024
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=512
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=1024
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=512
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=1024
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=512
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# size=3
# stride=1
# pad=1
# filters=1024
# activation=leaky
# batch_normalize=1
# filters=512
# size=1
# stride=1
# pad=1
# activation=leaky
# stride=1
# size=5
# layers=-2
# stride=1
# size=9
# layers=-4
# stride=1
# size=13
# layers=-1,-3,-5,-6
# batch_normalize=1
# filters=512
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# size=3
# stride=1
# pad=1
# filters=1024
# activation=leaky
# batch_normalize=1
# filters=512
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# size=3
# stride=1
# pad=1
# filters=1024
# activation=leaky
# size=1
# stride=1
# pad=1
# filters=30
# activation=linear
# mask = 6,7,8
# anchors = 10,13,  16,30,  33,23,  30,61,  62,45,  59,119,  116,90,  156,198,  373,326
# classes=5
# num=9
# jitter=.3
# ignore_thresh = .7
# truth_thresh = 1
# random=1
# layers = -4
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
# stride=2
# layers = -1, 61
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# size=3
# stride=1
# pad=1
# filters=512
# activation=leaky
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# size=3
# stride=1
# pad=1
# filters=512
# activation=leaky
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# size=3
# stride=1
# pad=1
# filters=512
# activation=leaky
# size=1
# stride=1
# pad=1
# filters=30
# activation=linear
# mask = 3,4,5
# anchors = 10,13,  16,30,  33,23,  30,61,  62,45,  59,119,  116,90,  156,198,  373,326
# classes=5
# num=9
# jitter=.3
# ignore_thresh = .7
# truth_thresh = 1
# random=1
# layers = -4
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
# stride=2
# layers = -1, 36
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# size=3
# stride=1
# pad=1
# filters=256
# activation=leaky
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# size=3
# stride=1
# pad=1
# filters=256
# activation=leaky
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# size=3
# stride=1
# pad=1
# filters=256
# activation=leaky
# size=1
# stride=1
# pad=1
# filters=30
# activation=linear
# mask = 0,1,2
# anchors = 10,13,  16,30,  33,23,  30,61,  62,45,  59,119,  116,90,  156,198,  373,326
# classes=5
# num=9
# jitter=.3
# ignore_thresh = .7
# truth_thresh = 1
# random=1
# Model Summary: 225 layers, 6.25949e+07 parameters, 6.25949e+07 gradients
# Caching labels (509 found, 0 missing, 0 empty, 0 duplicate, for 509 images): 100% 509/509 [00:00<00:00, 11017.31it/s]
# Caching images (0.3GB): 100% 509/509 [00:00<00:00, 526.32it/s]
# Caching labels (509 found, 0 missing, 0 empty, 0 duplicate, for 509 images): 100% 509/509 [00:00<00:00, 9877.76it/s]
# Caching images (0.2GB): 100% 509/509 [00:00<00:00, 542.45it/s]
# Image sizes 512 - 512 train, 512 test
# Using 2 dataloader workers
# Starting training for 60 epochs...
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#       0/59     7.71G      4.12      3.67      2.33      10.1        17       512: 100% 51/51 [00:56<00:00,  1.12s/it]
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100% 51/51 [00:17<00:00,  2.94it/s]
#                  all       509       524         0         0    0.0607         0
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#       1/59     7.72G      3.54      2.04      2.29      7.87        19       512: 100% 51/51 [00:56<00:00,  1.11s/it]
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100% 51/51 [00:13<00:00,  3.74it/s]
#                  all       509       524    0.0755     0.269    0.0721     0.114
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#       2/59     7.72G      2.86      1.73      2.23      6.82        18       512: 100% 51/51 [00:56<00:00,  1.10s/it]
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100% 51/51 [00:13<00:00,  3.76it/s]
#                  all       509       524     0.147    0.0134    0.0931     0.023
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#       3/59     7.72G      2.56      1.39      2.16      6.11        18       512: 100% 51/51 [00:56<00:00,  1.10s/it]
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100% 51/51 [00:13<00:00,  3.77it/s]
#                  all       509       524     0.292     0.006     0.166    0.0116
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#       4/59     7.72G      2.27      1.38      2.23      5.87        14       512: 100% 51/51 [00:56<00:00,  1.10s/it]
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100% 51/51 [00:13<00:00,  3.76it/s]
#                  all       509       524     0.341    0.0331     0.186    0.0545
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#       5/59     7.72G      2.21       1.2      2.17      5.57        19       512: 100% 51/51 [00:56<00:00,  1.10s/it]
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100% 51/51 [00:13<00:00,  3.78it/s]
#                  all       509       524     0.249    0.0559     0.197    0.0872
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#       6/59     7.72G      2.17      1.12      2.15      5.44        22       512: 100% 51/51 [00:56<00:00,  1.10s/it]
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100% 51/51 [00:13<00:00,  3.65it/s]
#                  all       509       524     0.261    0.0415      0.17    0.0658
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#       7/59     7.72G      1.93      1.02      2.06      5.01        17       512: 100% 51/51 [00:56<00:00,  1.10s/it]
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100% 51/51 [00:13<00:00,  3.75it/s]
#                  all       509       524     0.267     0.163     0.251     0.188
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#       8/59     7.72G      2.07      1.08       2.1      5.25        18       512: 100% 51/51 [00:56<00:00,  1.10s/it]
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100% 51/51 [00:13<00:00,  3.79it/s]
#                  all       509       524     0.316     0.146     0.259      0.17
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#       9/59     7.72G      2.08     0.965      2.16      5.21        19       512:  80% 41/51 [00:45<00:10,  1.09s/it]
# Model Bias Summary:    layer        regression        objectness    classification
#                           89       0.01+/-0.20      -5.18+/-0.95      -1.74+/-0.12
#                          101       0.16+/-0.22      -6.20+/-0.34      -1.77+/-0.19
#                          113      -0.00+/-0.04      -6.31+/-0.23      -1.90+/-0.04
#       9/59     7.72G      2.04     0.976      2.15      5.16        16       512: 100% 51/51 [00:56<00:00,  1.10s/it]
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100% 51/51 [00:13<00:00,  3.76it/s]
#                  all       509       524     0.263     0.106     0.232     0.121
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      10/59     7.72G      1.73      1.03       2.1      4.86        25       512: 100% 51/51 [00:56<00:00,  1.10s/it]
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100% 51/51 [00:13<00:00,  3
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      41/59     7.72G      1.12     0.707      1.03      2.86        18       512: 100% 51/51 [00:56<00:00,  1.10s/it]
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100% 51/51 [00:13<00:00,  3.79it/s]
#                  all       509       524     0.729     0.722     0.747       0.7
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      42/59     7.72G      1.12     0.669     0.872      2.66        17       512: 100% 51/51 [00:56<00:00,  1.10s/it]
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100% 51/51 [00:13<00:00,  3.77it/s]
#                  all       509       524     0.725      0.74     0.761     0.712
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      43/59     7.72G     0.987     0.661      0.87      2.52        21       512: 100% 51/51 [00:56<00:00,  1.10s/it]
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100% 51/51 [00:13<00:00,  3.77it/s]
#                  all       509       524     0.711     0.725     0.759     0.693
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      44/59     7.72G      1.04     0.647     0.939      2.63        20       512: 100% 51/51 [00:56<00:00,  1.10s/it]
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100% 51/51 [00:13<00:00,  3.78it/s]
#                  all       509       524     0.721     0.705     0.736     0.683
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      45/59     7.72G      1.03     0.655     0.925      2.61        18       512: 100% 51/51 [00:56<00:00,  1.10s/it]
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100% 51/51 [00:13<00:00,  3.75it/s]
#                  all       509       524      0.64     0.639     0.709     0.617
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      46/59     7.72G      1.18     0.658      1.03      2.87        18       512: 100% 51/51 [00:56<00:00,  1.10s/it]
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100% 51/51 [00:13<00:00,  3.78it/s]
#                  all       509       524     0.808     0.761     0.801     0.753
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      47/59     7.72G      1.14     0.648     0.851      2.64        18       512: 100% 51/51 [00:56<00:00,  1.10s/it]
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100% 51/51 [00:13<00:00,  3.77it/s]
#                  all       509       524     0.801     0.747     0.773     0.725
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      48/59     7.72G      1.09      0.67     0.858      2.62        18       512: 100% 51/51 [00:56<00:00,  1.10s/it]
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100% 51/51 [00:13<00:00,  3.77it/s]
#                  all       509       524     0.765     0.721     0.767     0.724
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      49/59     7.72G      1.07     0.679     0.836      2.58        16       512: 100% 51/51 [00:56<00:00,  1.10s/it]
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100% 51/51 [00:13<00:00,  3.76it/s]
#                  all       509       524     0.841     0.765     0.785     0.761
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      50/59     7.72G     0.912     0.627      0.75      2.29        19       512: 100% 51/51 [00:56<00:00,  1.10s/it]
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100% 51/51 [00:13<00:00,  3.73it/s]
#                  all       509       524     0.827     0.757     0.779     0.731
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      51/59     7.72G     0.968     0.656     0.855      2.48        18       512: 100% 51/51 [00:56<00:00,  1.10s/it]
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100% 51/51 [00:13<00:00,  3.79it/s]
#                  all       509       524     0.812     0.767     0.781     0.742
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      52/59     7.72G      1.05     0.646     0.795      2.49        22       512: 100% 51/51 [00:56<00:00,  1.10s/it]
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100% 51/51 [00:13<00:00,  3.77it/s]
#                  all       509       524     0.771     0.766     0.785     0.744
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      53/59     7.72G       0.9     0.639     0.785      2.32        21       512: 100% 51/51 [00:56<00:00,  1.10s/it]
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100% 51/51 [00:13<00:00,  3.78it/s]
#                  all       509       524      0.81     0.758     0.785     0.746
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      54/59     7.72G     0.999     0.609     0.809      2.42        17       512: 100% 51/51 [00:56<00:00,  1.10s/it]
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100% 51/51 [00:13<00:00,  3.78it/s]
#                  all       509       524     0.825     0.767     0.793     0.754
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      55/59     7.72G     0.872     0.608     0.731      2.21        20       512: 100% 51/51 [00:56<00:00,  1.10s/it]
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100% 51/51 [00:13<00:00,  3.77it/s]
#                  all       509       524     0.839     0.773     0.795     0.762
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      56/59     7.72G     0.935     0.595     0.809      2.34        19       512: 100% 51/51 [00:56<00:00,  1.10s/it]
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100% 51/51 [00:13<00:00,  3.74it/s]
#                  all       509       524     0.832     0.777     0.801     0.766
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      57/59     7.72G      1.11     0.653     0.736       2.5        23       512: 100% 51/51 [00:56<00:00,  1.10s/it]
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100% 51/51 [00:13<00:00,  3.75it/s]
#                  all       509       524     0.839     0.781     0.812     0.769
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      58/59     7.72G     0.944     0.627     0.762      2.33        19       512: 100% 51/51 [00:56<00:00,  1.10s/it]
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100% 51/51 [00:13<00:00,  3.76it/s]
#                  all       509       524     0.827     0.773      0.81     0.756
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      59/59     7.72G     0.904     0.633     0.717      2.25        21       512: 100% 51/51 [00:56<00:00,  1.10s/it]
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100% 51/51 [00:13<00:00,  3.78it/s]
#                  all       509       524     0.841     0.772     0.803     0.759
# 60 epochs completed in 1.166 hours.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# **8. Test the model & Save all the results in out_out/**

# %%
# !python detect.py --conf-thres 0.1 --output out_out
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.1, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='out_out', save_txt=False, source='data/customdata/images', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# batch=64
# subdivisions=16
# width=608
# height=608
# channels=3
# momentum=0.9
# decay=0.0005
# angle=0
# saturation = 1.5
# exposure = 1.5
# hue=.1
# learning_rate=0.001
# burn_in=1000
# max_batches = 500200
# policy=steps
# steps=400000,450000
# scales=.1,.1
# batch_normalize=1
# filters=32
# size=3
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=64
# size=3
# stride=2
# pad=1
# activation=leaky
# batch_normalize=1
# filters=32
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=64
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=128
# size=3
# stride=2
# pad=1
# activation=leaky
# batch_normalize=1
# filters=64
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=128
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=64
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=128
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=256
# size=3
# stride=2
# pad=1
# activation=leaky
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=256
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=256
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=256
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=256
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=256
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=256
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=256
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=256
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=512
# size=3
# stride=2
# pad=1
# activation=leaky
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=512
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=512
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=512
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=512
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=512
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=512
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=512
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=512
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=1024
# size=3
# stride=2
# pad=1
# activation=leaky
# batch_normalize=1
# filters=512
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=1024
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=512
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=1024
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=512
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=1024
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=512
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=1024
# size=3
# stride=1
# pad=1
# activation=leaky
# from=-3
# activation=linear
# batch_normalize=1
# filters=512
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# size=3
# stride=1
# pad=1
# filters=1024
# activation=leaky
# batch_normalize=1
# filters=512
# size=1
# stride=1
# pad=1
# activation=leaky
# stride=1
# size=5
# layers=-2
# stride=1
# size=9
# layers=-4
# stride=1
# size=13
# layers=-1,-3,-5,-6
# batch_normalize=1
# filters=512
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# size=3
# stride=1
# pad=1
# filters=1024
# activation=leaky
# batch_normalize=1
# filters=512
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# size=3
# stride=1
# pad=1
# filters=1024
# activation=leaky
# size=1
# stride=1
# pad=1
# filters=30
# activation=linear
# mask = 6,7,8
# anchors = 10,13,  16,30,  33,23,  30,61,  62,45,  59,119,  116,90,  156,198,  373,326
# classes=5
# num=9
# jitter=.3
# ignore_thresh = .7
# truth_thresh = 1
# random=1
# layers = -4
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
# stride=2
# layers = -1, 61
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# size=3
# stride=1
# pad=1
# filters=512
# activation=leaky
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# size=3
# stride=1
# pad=1
# filters=512
# activation=leaky
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# size=3
# stride=1
# pad=1
# filters=512
# activation=leaky
# size=1
# stride=1
# pad=1
# filters=30
# activation=linear
# mask = 3,4,5
# anchors = 10,13,  16,30,  33,23,  30,61,  62,45,  59,119,  116,90,  156,198,  373,326
# classes=5
# num=9
# jitter=.3
# ignore_thresh = .7
# truth_thresh = 1
# random=1
# layers = -4
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
# stride=2
# layers = -1, 36
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# size=3
# stride=1
# pad=1
# filters=256
# activation=leaky
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# size=3
# stride=1
# pad=1
# filters=256
# activation=leaky
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# size=3
# stride=1
# pad=1
# filters=256
# activation=leaky
# size=1
# stride=1
# pad=1
# filters=30
# activation=linear
# mask = 0,1,2
# anchors = 10,13,  16,30,  33,23,  30,61,  62,45,  59,119,  116,90,  156,198,  373,326
# classes=5
# num=9
# jitter=.3
# ignore_thresh = .7
# truth_thresh = 1
# random=1
# Model Summary: 225 layers, 6.25949e+07 parameters, 6.25949e+07 gradients
# image 1/509 data/customdata/images/cardboard001.jpg: 384x512 1 Cardboard-Recyclables, Done. (0
jpg: 384x512 1 Cardboard-Recyclables, Done. (0.021s)
# image 73/509 data/customdata/images/cardboard073.jpg: 384x512 1 Cardboard-Recyclables, Done. (0.021s)
# image 74/509 data/customdata/images/cardboard074.jpg: 384x512 1 Cardboard-Recyclables, Done. (0.020s)
# image 75/509 data/customdata/images/cardboard075.jpg: 384x512 1 Cardboard-Recyclables, Done. (0.021s)
# image 76/509 data/customdata/images/cardboard076.jpg: 384x512 1 Cardboard-Recyclables, Done. (0.020s)
# image 77/509 data/customdata/images/cardboard077.jpg: 384x512 1 Cardboard-Recyclables, Done. (0.021s)
# image 78/509 data/customdata/images/cardboard078.jpg: 384x512 1 Cardboard-Recyclables, Done. (0.021s)
# image 79/509 data/customdata/images/cardboard079.jpg: 384x512 1 Cardboard-Recyclables, Done. (0.020s)
# image 80/509 data/customdata/images/cardboard080.jpg: 384x512 1 Cardboard-Recyclables, Done. (0.020s)
# image 81/509 data/customdata/images/cardboard081.jpg: 384x512 1 Cardboard-Recyclables, Done. (0.020s)
# image 82/509 data/customdata/images/cardboard082.jpg: 512x512 1 Cardboard-Recyclables, Done. (0.025s)
# image 83/509 data/customdata/images/cardboard083.jpg: 512x512 1 Cardboard-Recyclables, Done. (0.027s)
# image 84/509 data/customdata/images/cardboard084.jpg: 512x512 1 Cardboard-Recyclables, Done. (0.027s)
# image 85/509 data/customdata/images/cardboard085.jpg: 320x512 1 Cardboard-Recyclables, Done. (0.020s)
# image 86/509 data/customdata/images/cardboard086.jpg: 384x512 1 Cardboard-Recyclables, Done. (0.021s)
# image 87/509 data/customdata/images/cardboard087.jpg: 512x512 1 Cardboard-Recyclables, Done. (0.026s)
# image 88/509 data/customdata/images/cardboard088.jpg: 384x512 1 Cardboard-Recyclables, Done. (0.021s)
# image 89/509 data/customdata/images/cardboard089.jpg: 384x512 1 Cardboard-Recyclables, Done. (0.021s)
# image 90/509 data/customdata/images/cardboard090.jpg: 384x512 1 Cardboard-Recyclables, Done. (0.022s)
# image 91/509 data/customdata/images/cardboard091.jpg: 384x512 1 Cardboard-Recyclables, Done. (0.022s)
# image 92/509 data/customdata/images/cardboard092.jpg: 320x512 1 Cardboard-Recyclables, Done. (0.018s)
# image 93/509 data/customdata/images/cardboard093.jpg: 384x512 1 Cardboard-Recyclables, Done. (0.021s)
# image 94/509 data/customdata/images/cardboard094.jpg: 320x512 1 Cardboard-Recyclables, Done. (0.019s)
# image 95/509 data/customdata/images/cardboard095.jpg: 512x512 1 PaperTowels-NonRecyclables, 1 Cardboard-Recyclables, Done. (0.026s)
# image 96/509 data/customdata/images/cardboard096.jpg: 384x512 1 Cardboard-Recyclables, Done. (0.022s)
# image 97/509 data/customdata/images/cardboard097.jpg: 320x512 1 Cardboard-Recyclables, Done. (0.019s)
# image 98/509 data/customdata/images/cardboard098.jpg: 512x512 1 Cardboard-Recyclables, Done. (0.026s)
# image 99/509 data/customdata/images/cardboard099.jpg: 384x512 1 Cardboard-Recyclables, Done. (0.022s)
# image 100/509 data/customdata/images/cardboard100.jpg: 512x512 1 Cardboard-Recyclables, Done. (0.026s)
# image 101/509 data/customdata/images/cardboard101.jpg: 320x512 1 Cardboard-Recyclables, Done. (0.020s)
# image 102/509 data/customdata/images/cardboard102.jpg: 384x512 1 Cardboard-Recyclables, Done. (0.023s)
# image 103/509 data/customdata/images/cardboard103.jpg: 512x512 1 Cardboard-Recyclables, Done. (0.026s)
# image 104/509 data/customdata/images/cardboard104.jpg: 384x512 1 Cardboard-Recyclables, Done. (0.022s)
# image 105/509 data/customdata/images/cardboard105.jpg: 384x512 1 Cardboard-Recyclables, Done. (0.020s)
# image 106/509 data/customdata/images/metalcan001.jpg: 512x512 2 MetalCans-Recylables, Done. (0.026s)
# image 107/509 data/customdata/images/metalcan002.jpg: 384x512 1 MetalCans-Recylables, Done. (0.020s)
# image 108/509 data/customdata/images/metalcan003.jpg: 512x512 1 MetalCans-Recylables, Done. (0.026s)
# image 109/509 data/customdata/images/metalcan004.jpg: 384x512 1 MetalCans-Recylables, Done. (0.022s)
# image 110/509 data/customdata/images/metalcan005.jpg: 512x256 1 MetalCans-Recylables, Done. (0.017s)
# image 111/509 data/customdata/images/metalcan006.jpg: 512x256 1 PaperTowels-NonRecyclables, 1 MetalCans-Recylables, Done. (0.016s)
# image 112/509 data/customdata/images/metalcan007.jpg: 512x512 1 MetalCans-Recylables, Done. (0.025s)
# image 113/509 data/customdata/images/metalcan008.jpg: 512x512 1 MetalCans-Recylables, Done. (0.025s)
# image 114/509 data/customdata/images/metalcan009.jpg: 384x512 1 MetalCans-Recylables, Done. (0.022s)
# image 115/509 data/customdata/images/metalcan010.jpg: 512x512 1 MetalCans-Recylables, Done. (0.026s)
# image 116/509 data/customdata/images/metalcan011.jpg: 384x512 1 MetalCans-Recylables, Done. (0.022s)
# image 117/509 data/customdata/images/metalcan012.jpg: 512x384 1 MetalCans-Recylables, Done. (0.022s)
# image 118/509 data/customdata/images/metalcan013.jpg: 320x512 2 MetalCans-Recylables, 1 Cardboard-Recyclables, Done. (0.018s)
# image 119/509 data/customdata/images/metalcan015.jpg: 448x512 1 MetalCans-Recylables, Done. (0.024s)
# image 120/509 data/customdata/images/metalcan016.jpg: 448x512 1 MetalCans-Recylables, Done. (0.025s)
# image 121/509 data/customdata/images/metalcan017.jpg: 384x512 2 MetalCans-Recylables, Done. (0.021s)
# image 122/509 data/customdata/images/metalcan018.jpg: 512x512 1 MetalCans-Recylables, Done. (0.026s)
# image 123/509 data/customdata/images/metalcan019.jpg: 512x384 1 MetalCans-Recylables, Done. (0.022s)
# image 124/509 data/customdata/images/metalcan020.jpg: 384x512 1 MetalCans-Recylables, Done. (0.022s)
# image 125/509 data/customdata/images/metalcan021.jpg: 512x512 1 MetalCans-Recylables, Done. (0.025s)
# image 126/509 data/customdata/images/metalcan022.jpg: 384x512 1 MetalCans-Recylables, Done. (0.022s)
# image 127/509 data/customdata/images/metalcan023.jpg: 384x512 1 MetalCans-Recylables, Done. (0.021s)
# image 128/509 data/customdata/images/metalcan024.jpg: 384x512 1 MetalCans-Recylables, Done. (0.022s)
# image 129/509 data/customdata/images/metalcan025.jpg: 384x512 1 MetalCans-Recylables, Done. (0.021s)
# image 130/509 data/customdata/images/metalcan026.jpg: 384x512 1 MetalCans-Recylables, Done. (0.020s)
# image 131/509 data/customdata/images/metalcan027.jpg: 384x512 1 MetalCans-Recylables, Done. (0.021s)
# image 132/509 data/customdata/images/metalcan028.jpg: 384x512 1 MetalCans-Recylables, Done. (0.020s)
# image 133/509 data/customdata/images/metalcan029.jpg: 384x512 1 MetalCans-Recylables, Done. (0.021s)
# image 134/509 data/customdata/images/metalcan030.jpg: 384x512 1 MetalCans-Recylables, Done. (0.020s)
# image 135/509 data/customdata/images/metalcan031.jpg: 384x512 1 MetalCans-Recylables, Done. (0.021s)
# image 136/509 data/customdata/images/metalcan032.jpg: 384x512 1 MetalCans-Recylables, Done. (0.020s)
# image 137/509 data/customdata/images/metalcan033.jpg: 384x512 1 MetalCans-Recylables, Done. (0.020s)
# image 138/509 data/customdata/images/metalcan034.jpg: 384x512 1 MetalCans-Recylables, Done. (0.020s)
# image 139/509 data/customdata/images/metalcan035.jpg: 320x512 2 MetalCans-Recylables, Done. (0.018s)
# image 140/509 data/customdata/images/metalcan036.jpg: 512x512 1 MetalCans-Recylables, Done. (0.026s)
# image 141/509 data/customdata/images/metalcan037.jpg: 512x448 1 MetalCans-Recylables, Done. (0.024s)
# image 142/509 data/customdata/images/metalcan038.jpg: 448x512 1 MetalCans-Recylables, Done. (0.024s)
# image 143/509 data/customdata/images/metalcan039.jpg: 320x512 2 MetalCans-Recylables, Done. (0.018s)
# image 144/509 data/customdata/images/metalcan040.jpg: 384x512 1 MetalCans-Recylables, Done. (0.021s)
# image 145/509 data/customdata/images/metalcan041.jpg: 384x512 1 MetalCans-Recylables, Done. (0.022s)
# image 146/509 data/customdata/images/metalcan042.jpg: 512x512 1 MetalCans-Recylables, Done. (0.025s)
# image 147/509 data/customdata/images/metalcan043.jpg: 384x512 1 MetalCans-Recylables, Done. (0.022s)
# image 148/509 data/customdata/images/metalcan044.jpg: 384x512 1 MetalCans-Recylables, Done. (0.020s)
# image 149/509 data/customdata/images/metalcan045.jpg: 384x512 1 MetalCans-Recylables, Done. (0.021s)
# image 150/509 data/customdata/images/metalcan046.jpg: 384x512 1 MetalCans-Recylables, Done. (0.020s)
# image 151/509 data/customdata/images/metalcan047.jpg: 384x512 1 MetalCans-Recylables, Done. (0.021s)
# image 152/509 data/customdata/images/metalcan048.jpg: 384x512 1 MetalCans-Recylables, Done. (0.020s)
# image 153/509 data/customdata/images/metalcan049.jpg: 512x512 1 MetalCans-Recylables, Done. (0.025s)
# image 154/509 data/customdata/images/metalcan050.jpg: 384x512 1 MetalCans-Recylables, Done. (0.022s)
# image 155/509 data/customdata/images/metalcan051.jpg: 512x448 2 MetalCans-Recylables, Done. (0.024s)
# image 156/509 data/customdata/images/metalcan052.jpg: 384x512 1 MetalCans-Recylables, Done. (0.021s)
# image 157/509 data/customdata/images/metalcan053.jpg: 384x512 1 MetalCans-Recylables, Done. (0.020s)
# image 158/509 data/customdata/images/metalcan054.jpg: 384x512 1 MetalCans-Recylables, Done. (0.021s)
# image 159/509 data/customdata/images/metalcan055.jpg: 448x512 1 MetalCans-Recylables, Done. (0.022s)
# image 160/509 data/customdata/images/metalcan056.jpg: 512x512 1 MetalCans-Recylables, 1 Cardboard-Recyclables, Done. (0.026s)
# image 161/509 data/customdata/images/metalcan057.jpg: 384x512 1 MetalCans-Recylables, Done. (0.021s)
# image 162/509 data/customdata/images/metalcan058.jpg: 384x512 1 MetalCans-Recylables, Done. (0.022s)
# image
jpg: 512x512 1 PaperTowels-NonRecyclables, Done. (0.025s)
# image 365/509 data/customdata/images/papertowel011.jpg: 512x512 1 PaperTowels-NonRecyclables, Done. (0.027s)
# image 366/509 data/customdata/images/papertowel012.jpg: 448x512 2 PaperTowels-NonRecyclables, Done. (0.025s)
# image 367/509 data/customdata/images/papertowel013.jpg: 384x512 1 PaperTowels-NonRecyclables, Done. (0.022s)
# image 368/509 data/customdata/images/papertowel014.jpg: 512x512 1 PaperTowels-NonRecyclables, Done. (0.025s)
# image 369/509 data/customdata/images/papertowel015.jpg: 384x512 5 PaperTowels-NonRecyclables, Done. (0.022s)
# image 370/509 data/customdata/images/papertowel016.jpg: 512x512 Done. (0.027s)
# image 371/509 data/customdata/images/papertowel017.jpg: 384x512 1 PaperTowels-NonRecyclables, Done. (0.023s)
# image 372/509 data/customdata/images/papertowel018.jpg: 512x512 1 PaperTowels-NonRecyclables, Done. (0.027s)
# image 373/509 data/customdata/images/papertowel019.jpg: 384x512 2 PaperTowels-NonRecyclables, Done. (0.022s)
# image 374/509 data/customdata/images/papertowel020.jpg: 384x512 2 PaperTowels-NonRecyclables, Done. (0.022s)
# image 375/509 data/customdata/images/papertowel021.jpg: 384x512 1 PaperTowels-NonRecyclables, Done. (0.021s)
# image 376/509 data/customdata/images/papertowel022.jpg: 512x384 1 PaperTowels-NonRecyclables, Done. (0.023s)
# image 377/509 data/customdata/images/papertowel023.jpg: 512x512 1 PaperTowels-NonRecyclables, Done. (0.026s)
# image 378/509 data/customdata/images/papertowel024.jpg: 512x384 1 PaperTowels-NonRecyclables, Done. (0.024s)
# image 379/509 data/customdata/images/papertowel025.jpg: 512x512 2 PaperTowels-NonRecyclables, Done. (0.027s)
# image 380/509 data/customdata/images/papertowel026.jpg: 384x512 2 PaperTowels-NonRecyclables, Done. (0.023s)
# image 381/509 data/customdata/images/papertowel027.jpg: 384x512 1 PaperTowels-NonRecyclables, Done. (0.022s)
# image 382/509 data/customdata/images/papertowel028.jpg: 320x512 2 PaperTowels-NonRecyclables, Done. (0.019s)
# image 383/509 data/customdata/images/papertowel029.jpg: 512x512 1 PaperTowels-NonRecyclables, Done. (0.027s)
# image 384/509 data/customdata/images/papertowel030.jpg: 320x512 2 PaperTowels-NonRecyclables, Done. (0.019s)
# image 385/509 data/customdata/images/papertowel031.jpg: 512x512 2 PaperTowels-NonRecyclables, Done. (0.028s)
# image 386/509 data/customdata/images/papertowel032.jpg: 512x512 1 PaperTowels-NonRecyclables, Done. (0.026s)
# image 387/509 data/customdata/images/papertowel033.jpg: 512x512 Done. (0.027s)
# image 388/509 data/customdata/images/papertowel034.jpg: 512x512 2 PaperTowels-NonRecyclables, Done. (0.026s)
# image 389/509 data/customdata/images/papertowel035.jpg: 512x512 3 PaperTowels-NonRecyclables, Done. (0.027s)
# image 390/509 data/customdata/images/papertowel036.jpg: 512x512 1 PaperTowels-NonRecyclables, Done. (0.028s)
# image 391/509 data/customdata/images/papertowel037.jpg: 512x512 1 PaperTowels-NonRecyclables, Done. (0.027s)
# image 392/509 data/customdata/images/papertowel038.jpg: 320x512 2 PaperTowels-NonRecyclables, Done. (0.020s)
# image 393/509 data/customdata/images/papertowel039.jpg: 384x512 2 PaperTowels-NonRecyclables, Done. (0.022s)
# image 394/509 data/customdata/images/papertowel040.jpg: 512x512 1 PaperTowels-NonRecyclables, Done. (0.026s)
# image 395/509 data/customdata/images/papertowel041.jpg: 512x512 1 PaperTowels-NonRecyclables, Done. (0.027s)
# image 396/509 data/customdata/images/papertowel042.jpg: 512x448 1 PaperTowels-NonRecyclables, Done. (0.026s)
# image 397/509 data/customdata/images/papertowel043.jpg: 512x512 3 PaperTowels-NonRecyclables, Done. (0.027s)
# image 398/509 data/customdata/images/papertowel044.jpg: 512x384 1 PaperTowels-NonRecyclables, Done. (0.024s)
# image 399/509 data/customdata/images/papertowel045.jpg: 512x512 1 PaperTowels-NonRecyclables, Done. (0
jpg: 384x512 1 Plastic-Recyclables, Done. (0.021s)
# image 470/509 data/customdata/images/plastic066.jpg: 384x512 1 Plastic-Recyclables, Done. (0.021s)
# image 471/509 data/customdata/images/plastic067.jpg: 384x512 1 Plastic-Recyclables, Done. (0.021s)
# image 472/509 data/customdata/images/plastic068.jpg: 384x512 1 Plastic-Recyclables, Done. (0.020s)
# image 473/509 data/customdata/images/plastic069.jpg: 384x512 1 Plastic-Recyclables, Done. (0.022s)
# image 474/509 data/customdata/images/plastic070.jpg: 384x512 1 Plastic-Recyclables, Done. (0.020s)
# image 475/509 data/customdata/images/plastic071.jpg: 384x512 1 Plastic-Recyclables, Done. (0.021s)
# image 476/509 data/customdata/images/plastic072.jpg: 384x512 1 Plastic-Recyclables, Done. (0.021s)
# image 477/509 data/customdata/images/plastic073.jpg: 384x512 1 Plastic-Recyclables, Done. (0.021s)
# image 478/509 data/customdata/images/plastic074.jpg: 384x512 1 Plastic-Recyclables, Done. (0.021s)
# image 479/509 data/customdata/images/plastic075.jpg: 384x512 1 Plastic-Recyclables, Done. (0.020s)
# image 480/509 data/customdata/images/plastic076.jpg: 384x512 1 Plastic-Recyclables, Done. (0.022s)
# image 481/509 data/customdata/images/plastic077.jpg: 384x512 1 Plastic-Recyclables, Done. (0.020s)
# image 482/509 data/customdata/images/plastic078.jpg: 384x512 1 Plastic-Recyclables, Done. (0.021s)
# image 483/509 data/customdata/images/plastic079.jpg: 384x512 1 Plastic-Recyclables, Done. (0.020s)
# image 484/509 data/customdata/images/plastic080.jpg: 384x512 1 Plastic-Recyclables, Done. (0.022s)
# image 485/509 data/customdata/images/plastic081.jpg: 384x512 1 Plastic-Recyclables, Done. (0.021s)
# image 486/509 data/customdata/images/plastic082.jpg: 384x512 1 Plastic-Recyclables, Done. (0.021s)
# image 487/509 data/customdata/images/plastic083.jpg: 384x512 1 Plastic-Recyclables, Done. (0.021s)
# image 488/509 data/customdata/images/plastic084.jpg: 384x512 1 Plastic-Recyclables, Done. (0.021s)
# image 489/509 data/customdata/images/plastic085.jpg: 384x512 1 Plastic-Recyclables, Done. (0.022s)
# image 490/509 data/customdata/images/plastic086.jpg: 384x512 1 Plastic-Recyclables, Done. (0.020s)
# image 491/509 data/customdata/images/plastic087.jpg: 384x512 1 Plastic-Recyclables, Done. (0.022s)
# image 492/509 data/customdata/images/plastic088.jpg: 384x512 1 Plastic-Recyclables, Done. (0.021s)
# image 493/509 data/customdata/images/plastic089.jpg: 384x512 1 Plastic-Recyclables, Done. (0.021s)
# image 494/509 data/customdata/images/plastic090.jpg: 384x512 1 Plastic-Recyclables, Done. (0.020s)
# image 495/509 data/customdata/images/plastic091.jpg: 384x512 1 Plastic-Recyclables, Done. (0.020s)
# image 496/509 data/customdata/images/plastic092.jpg: 384x512 1 Plastic-Recyclables, Done. (0.021s)
# image 497/509 data/customdata/images/plastic093.jpg: 384x512 1 Plastic-Recyclables, Done. (0.020s)
# image 498/509 data/customdata/images/plastic094.jpg: 384x512 1 Plastic-Recyclables, Done. (0.022s)
# image 499/509 data/customdata/images/plastic095.jpg: 384x512 1 Plastic-Recyclables, Done. (0.021s)
# image 500/509 data/customdata/images/plastic096.jpg: 384x512 1 Plastic-Recyclables, Done. (0.022s)
# image 501/509 data/customdata/images/plastic097.jpg: 384x512 1 Plastic-Recyclables, Done. (0.021s)
# image 502/509 data/customdata/images/plastic098.jpg: 384x512 1 Plastic-Recyclables, Done. (0.021s)
# image 503/509 data/customdata/images/plastic099.jpg: 384x512 1 Plastic-Recyclables, Done. (0.021s)
# image 504/509 data/customdata/images/plastic100.jpg: 384x512 1 Plastic-Recyclables, Done. (0.020s)
# image 505/509 data/customdata/images/plastic101.jpg: 384x512 1 Plastic-Recyclables, Done. (0.022s)
# image 506/509 data/customdata/images/plastic102.jpg: 384x512 1 Plastic-Recyclables, Done. (0.021s)
# image 507/509 data/customdata/images/plastic103.jpg: 384x512 1 Plastic-Recyclables, Done. (0.021s)
# image 508/509 data/customdata/images/plastic104.jpg: 384x512 1 Plastic-Recyclables, Done. (0.022s)
# image 509/509 data/customdata/images/plastic105.jpg: 384x512 1 Plastic-Recyclables, Done. (0.021s)
# Results saved to /content/YoloV3/out_out
# Done. (14.833s)

# %% [markdown]
# # ***Test Results***

# %%
Image(filename='out_out/cardboard016.jpg', width=600)

# %%
Image(filename='out_out/cardboard068.jpg', width=600)

# %%
Image(filename='out_out/metalcan012.jpg', width=600)

# %%
Image(filename='out_out/metalcan048.jpg', width=600)

# %%
Image(filename='out_out/metalcan013.jpg', width=600)

# %%
Image(filename='out_out/paper018.jpg', width=600)

# %%
Image(filename='out_out/paper073.jpg', width=600)

# %%
Image(filename='out_out/paper002.jpg', width=600)

# %%
Image(filename='out_out/paper029.jpg', width=600)

# %%
Image(filename='out_out/papertowel021.jpg', width=600)

# %%
Image(filename='out_out/papertowel031.jpg', width=600)

# %%
Image(filename='out_out/papertowel041.jpg', width=600)

# %%
Image(filename='out_out/plastic008.jpg', width=600)

# %%
Image(filename='out_out/plastic091.jpg', width=600)

# %%
Image(filename='out_out/plastic055.jpg', width=600)

# %%
! cd YoloV3/
# !ls
# Out:
# /bin/bash: line 0: cd: YoloV3/: No such file or directory
#  annotation_tool   out_out	  results.txt	     train.py
#  cfg		   output	  runs		    'ubdivisions=1'
#  data		   __pycache__	  test_batch0.png    utils
#  detect.py	   README.md	  test.py	     vim.exe.stackdump
#  last.pt	   results.json   ting		     weights
#  models.py	   results.png	  train_batch0.png

# %% [markdown]
# **Use this command to move model**

# %%
# !mv "/content/YoloV3/last.pt" "/content/gdrive/My Drive/yolo/"
